# %%
import pandas as pd
import json

# %%
DATA_PATH = "./MovieSummaries/"
movie_columns = ['WID', 'FID', 'MovieName', 'MovieReleaseDate', 'MovieBoxOfficeRevenue', 'MovieRuntime', 'MovieLanguages', 'MovieCountries', 'MovieGenres']

character_actor_columns = ['WikipediaMovieID','Freebase_MovieID','Movie_release_date','Character_Name','Actor_DOB','Actor_gender','Actor_height','Actor_ethnicity','Actor_Name','Actor_age_at_movie_release','Freebase_character_map1','Freebase_character_map2','Freebase_character_map3']

# %%
movie_data = pd.read_csv(DATA_PATH+"movie.metadata.tsv", sep='\t', names=movie_columns)
movie_data.head()
# Out:
#         WID         FID                                          MovieName  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
#
#   MovieReleaseDate  MovieBoxOfficeRevenue  MovieRuntime  \
# 0       2001-08-24             14010832.0          98.0
# 1       2000-02-16                    NaN          95.0
# 2             1988                    NaN          83.0
# 3             1987                    NaN         110.0
# 4             1983                    NaN         106.0
#
#                        MovieLanguages  \
# 0  {"/m/02h40lc": "English Language"}
# 1  {"/m/02h40lc": "English Language"}
# 2  {"/m/05f_3": "Norwegian Language"}
# 3  {"/m/02h40lc": "English Language"}
# 4   {"/m/04306rv": "German Language"}
#
#                               MovieCountries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                          MovieGenres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
char_actor_data = pd.read_csv(DATA_PATH+"character.metadata.tsv", sep='\t', names=character_actor_columns)
char_actor_data.head()
# Out:
#    WikipediaMovieID Freebase_MovieID Movie_release_date  \
# 0            975900        /m/03vyhn         2001-08-24
# 1            975900        /m/03vyhn         2001-08-24
# 2            975900        /m/03vyhn         2001-08-24
# 3            975900        /m/03vyhn         2001-08-24
# 4            975900        /m/03vyhn         2001-08-24
#
#                Character_Name   Actor_DOB Actor_gender  Actor_height  \
# 0                    Akooshay  1958-08-26            F         1.620
# 1  Lieutenant Melanie Ballard  1974-08-15            F         1.780
# 2         Desolation Williams  1969-06-15            M         1.727
# 3          Sgt Jericho Butler  1967-09-12            M         1.750
# 4             Bashira Kincaid  1977-09-25            F         1.650
#
#   Actor_ethnicity          Actor_Name  Actor_age_at_movie_release  \
# 0             NaN      Wanda De Jesus                        42.0
# 1      /m/044038p  Natasha Henstridge                        27.0
# 2         /m/0x67            Ice Cube                        32.0
# 3             NaN       Jason Statham                        33.0
# 4             NaN         Clea DuVall                        23.0
#
#   Freebase_character_map1 Freebase_character_map2 Freebase_character_map3
# 0              /m/0bgchxw              /m/0bgcj3x              /m/03wcfv7
# 1               /m/0jys3m              /m/0bgchn4               /m/0346l4
# 2               /m/0jys3g              /m/0bgchn_              /m/01vw26l
# 3              /m/02vchl6              /m/0bgchnq               /m/034hyc
# 4              /m/02vbb3r              /m/0bgchp9               /m/01y9xg

# %%
char_actor_movie_data = pd.merge(char_actor_data, movie_data, how='left', left_on=["WikipediaMovieID", "Freebase_MovieID", "Movie_release_date"], right_on=["WID", "FID", "MovieReleaseDate"]).copy()
char_actor_movie_data_dropped = char_actor_movie_data.drop(["WID", "FID", "MovieReleaseDate"], axis=1).copy()
display(char_actor_movie_data_dropped)
display(char_actor_movie_data_dropped.columns)
# Out:
#         WikipediaMovieID Freebase_MovieID Movie_release_date  \
# 0                 975900        /m/03vyhn         2001-08-24
# 1                 975900        /m/03vyhn         2001-08-24
# 2                 975900        /m/03vyhn         2001-08-24
# 3                 975900        /m/03vyhn         2001-08-24
# 4                 975900        /m/03vyhn         2001-08-24
# ...                  ...              ...                ...
# 450664            913762        /m/03pcrp         1992-05-21
# 450665            913762        /m/03pcrp         1992-05-21
# 450666          28308153       /m/0cp05t9               1957
# 450667          28308153       /m/0cp05t9               1957
# 450668          28308153       /m/0cp05t9               1957
#
#                     Character_Name   Actor_DOB Actor_gender  Actor_height  \
# 0                         Akooshay  1958-08-26            F         1.620
# 1       Lieutenant Melanie Ballard  1974-08-15            F         1.780
# 2              Desolation Williams  1969-06-15            M         1.727
# 3               Sgt Jericho Butler  1967-09-12            M         1.750
# 4                  Bashira Kincaid  1977-09-25            F         1.650
# ...                            ...         ...          ...           ...
# 450664                      Elensh     1970-05            F           NaN
# 450665                      Hibiki  1965-04-12            M           NaN
# 450666                         NaN  1941-11-18            M         1.730
# 450667                         NaN         NaN          NaN           NaN
# 450668                         NaN         NaN          NaN           NaN
#
#        Actor_ethnicity          Actor_Name  Actor_age_at_movie_release  \
# 0                  NaN      Wanda De Jesus                        42.0
# 1           /m/044038p  Natasha Henstridge                        27.0
# 2              /m/0x67            Ice Cube                        32.0
# 3                  NaN       Jason Statham                        33.0
# 4                  NaN         Clea DuVall                        23.0
# ...                ...                 ...                         ...
# 450664             NaN  Dorothy Elias-Fahn                         NaN
# 450665             NaN       Jonathan Fahn                        27.0
# 450666       /m/02w7gg      David Hemmings                        15.0
# 450667             NaN    Roberta Paterson                         NaN
# 450668             NaN         John Rogers                         NaN
#
#        Freebase_character_map1 Freebase_character_map2  \
# 0                   /m/0bgchxw              /m/0bgcj3x
# 1                    /m/0jys3m              /m/0bgchn4
# 2                    /m/0jys3g              /m/0bgchn_
# 3                   /m/02vchl6              /m/0bgchnq
# 4                   /m/02vbb3r              /m/0bgchp9
# ...                        ...                     ...
# 450664              /m/0kr406c              /m/0kr406h
# 450665              /m/0kr405_              /m/0kr4090
# 450666              /m/0g8ngmc                     NaN
# 450667              /m/0g8ngmj                     NaN
# 450668              /m/0g8ngmw                     NaN
#
#        Freebase_character_map3  \
# 0                   /m/03wcfv7
# 1                    /m/0346l4
# 2                   /m/01vw26l
# 3                    /m/034hyc
# 4                    /m/01y9xg
# ...                        ...
# 450664               /m/0b_vcv
# 450665               /m/0bx7_j
# 450666               /m/022g44
# 450667              /m/0g8ngmm
# 450668              /m/0btz19d
#
#                                                 MovieName  \
# 0                                          Ghosts of Mars
# 1                                          Ghosts of Mars
# 2                                          Ghosts of Mars
# 3                                          Ghosts of Mars
# 4                                          Ghosts of Mars
# ...                                                   ...
# 450664  The Super Dimension Fortress Macross II: Lover...
# 450665  The Super Dimension Fortress Macross II: Lover...
# 450666                              Five Clues to Fortune
# 450667                              Five Clues to Fortune
# 450668                              Five Clues to Fortune
#
#         MovieBoxOfficeRevenue  MovieRuntime  \
# 0                  14010832.0          98.0
# 1                  14010832.0          98.0
# 2                  14010832.0          98.0
# 3                  14010832.0          98.0
# 4                  14010832.0          98.0
# ...                       ...           ...
# 450664                    NaN         150.0
# 450665                    NaN         150.0
# 450666                    NaN         129.0
# 450667                    NaN         129.0
# 450668                    NaN         129.0
#
#                             MovieLanguages  \
# 0       {"/m/02h40lc": "English Language"}
# 1       {"/m/02h40lc": "English Language"}
# 2       {"/m/02h40lc": "English Language"}
# 3       {"/m/02h40lc": "English Language"}
# 4       {"/m/02h40lc": "English Language"}
# ...                                    ...
# 450664   {"/m/03_9r": "Japanese Language"}
# 450665   {"/m/03_9r": "Japanese Language"}
# 450666  {"/m/02h40lc": "English Language"}
# 450667  {"/m/02h40lc": "English Language"}
# 450668  {"/m/02h40lc": "English Language"}
#
#                                    MovieCountries  \
# 0       {"/m/09c7w0": "United States of America"}
# 1       {"/m/09c7w0": "United States of America"}
# 2       {"/m/09c7w0": "United States of America"}
# 3       {"/m/09c7w0": "United States of America"}
# 4       {"/m/09c7w0": "United States of America"}
# ...                                           ...
# 450664                      {"/m/03_3d": "Japan"}
# 450665                      {"/m/03_3d": "Japan"}
# 450666             {"/m/07ssc": "United Kingdom"}
# 450667             {"/m/07ssc": "United Kingdom"}
# 450668             {"/m/07ssc": "United Kingdom"}
#
#                                               MovieGenres
# 0       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 4       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# ...                                                   ...
# 450664  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 450665  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 450666                      {"/m/0lsxr": "Crime Fiction"}
# 450667                      {"/m/0lsxr": "Crime Fiction"}
# 450668                      {"/m/0lsxr": "Crime Fiction"}
#
# [450669 rows x 19 columns]
# Index(['WikipediaMovieID', 'Freebase_MovieID', 'Movie_release_date',
#        'Character_Name', 'Actor_DOB', 'Actor_gender', 'Actor_height',
#        'Actor_ethnicity', 'Actor_Name', 'Actor_age_at_movie_release',
#        'Freebase_character_map1', 'Freebase_character_map2',
#        'Freebase_character_map3', 'MovieName', 'MovieBoxOfficeRevenue',
#        'MovieRuntime', 'MovieLanguages', 'MovieCountries', 'MovieGenres'],
#       dtype='object')

# %%
# rename each column to snake case
char_actor_movie_data_renamed = char_actor_movie_data_dropped.rename(columns={'WikipediaMovieID': 'wiki_movie_id',
                                                  'Freebase_MovieID': 'freebase_movie_id',
                                                  'Movie_realse_date': 'movie_release_date',
                                                  'Character_Name': 'character_name',
                                                  'Actor_DOB': 'actor_dob',
                                                  'Actor_gender': 'actor_gender',
                                                  'Actor_height': 'actor_height',
                                                  'Actor_ethnicity': 'actor_ethnicity',
                                                  'Actor_Name': 'actor_name',
                                                  'Actor_age_at_movie_release': 'actor_age_at_movie_release',
                                                  'Freebase_character_map1': 'freebase_character_actor_map_id',
                                                  'Freebase_character_map2': 'freebase_character_id',
                                                  'Freebase_character_map3': 'freebase_actor_id',
                                                  'MovieName': 'movie_name',
                                                  'MovieBoxOfficeRevenue': 'movie_box_office_revenue',
                                                  'MovieRuntime': 'movie_runtime',
                                                  'MovieLanguages': 'movie_languages',
                                                  'MovieCountries': 'movie_countries',
                                                  'MovieGenres': 'movie_genres'}).copy()

# %%
# convert dictionaries to lists for movie_genres, movie_countries, movie_languages columns

genre_col = []
for l in char_actor_movie_data_renamed["movie_genres"].values:
    l = json.loads(l)
    genre_col.append(list(l.values()))

country_col = []
for l in char_actor_movie_data_renamed["movie_countries"].values:
    l = json.loads(l)
    country_col.append(list(l.values()))

language_col = []
for l in char_actor_movie_data_renamed["movie_languages"].values:
    l = json.loads(l)
    language_col.append(list(l.values()))

char_actor_movie_data_renamed["movie_genres"] = genre_col
char_actor_movie_data_renamed["movie_countries"] = country_col
char_actor_movie_data_renamed["movie_languages"] = language_col
char_actor_movie_data_new = char_actor_movie_data_renamed.copy()
display(char_actor_movie_data_new)
# Out:
#         wiki_movie_id freebase_movie_id Movie_release_date  \
# 0              975900         /m/03vyhn         2001-08-24
# 1              975900         /m/03vyhn         2001-08-24
# 2              975900         /m/03vyhn         2001-08-24
# 3              975900         /m/03vyhn         2001-08-24
# 4              975900         /m/03vyhn         2001-08-24
# ...               ...               ...                ...
# 450664         913762         /m/03pcrp         1992-05-21
# 450665         913762         /m/03pcrp         1992-05-21
# 450666       28308153        /m/0cp05t9               1957
# 450667       28308153        /m/0cp05t9               1957
# 450668       28308153        /m/0cp05t9               1957
#
#                     character_name   actor_dob actor_gender  actor_height  \
# 0                         Akooshay  1958-08-26            F         1.620
# 1       Lieutenant Melanie Ballard  1974-08-15            F         1.780
# 2              Desolation Williams  1969-06-15            M         1.727
# 3               Sgt Jericho Butler  1967-09-12            M         1.750
# 4                  Bashira Kincaid  1977-09-25            F         1.650
# ...                            ...         ...          ...           ...
# 450664                      Elensh     1970-05            F           NaN
# 450665                      Hibiki  1965-04-12            M           NaN
# 450666                         NaN  1941-11-18            M         1.730
# 450667                         NaN         NaN          NaN           NaN
# 450668                         NaN         NaN          NaN           NaN
#
#        actor_ethnicity          actor_name  actor_age_at_movie_release  \
# 0                  NaN      Wanda De Jesus                        42.0
# 1           /m/044038p  Natasha Henstridge                        27.0
# 2              /m/0x67            Ice Cube                        32.0
# 3                  NaN       Jason Statham                        33.0
# 4                  NaN         Clea DuVall                        23.0
# ...                ...                 ...                         ...
# 450664             NaN  Dorothy Elias-Fahn                         NaN
# 450665             NaN       Jonathan Fahn                        27.0
# 450666       /m/02w7gg      David Hemmings                        15.0
# 450667             NaN    Roberta Paterson                         NaN
# 450668             NaN         John Rogers                         NaN
#
#        freebase_character_actor_map_id freebase_character_id  \
# 0                           /m/0bgchxw            /m/0bgcj3x
# 1                            /m/0jys3m            /m/0bgchn4
# 2                            /m/0jys3g            /m/0bgchn_
# 3                           /m/02vchl6            /m/0bgchnq
# 4                           /m/02vbb3r            /m/0bgchp9
# ...                                ...                   ...
# 450664                      /m/0kr406c            /m/0kr406h
# 450665                      /m/0kr405_            /m/0kr4090
# 450666                      /m/0g8ngmc                   NaN
# 450667                      /m/0g8ngmj                   NaN
# 450668                      /m/0g8ngmw                   NaN
#
#        freebase_actor_id                                         movie_name  \
# 0             /m/03wcfv7                                     Ghosts of Mars
# 1              /m/0346l4                                     Ghosts of Mars
# 2             /m/01vw26l                                     Ghosts of Mars
# 3              /m/034hyc                                     Ghosts of Mars
# 4              /m/01y9xg                                     Ghosts of Mars
# ...                  ...                                                ...
# 450664         /m/0b_vcv  The Super Dimension Fortress Macross II: Lover...
# 450665         /m/0bx7_j  The Super Dimension Fortress Macross II: Lover...
# 450666         /m/022g44                              Five Clues to Fortune
# 450667        /m/0g8ngmm                              Five Clues to Fortune
# 450668        /m/0btz19d                              Five Clues to Fortune
#
#         movie_box_office_revenue  movie_runtime      movie_languages  \
# 0                     14010832.0           98.0   [English Language]
# 1                     14010832.0           98.0   [English Language]
# 2                     14010832.0           98.0   [English Language]
# 3                     14010832.0           98.0   [English Language]
# 4                     14010832.0           98.0   [English Language]
# ...                          ...            ...                  ...
# 450664                       NaN          150.0  [Japanese Language]
# 450665                       NaN          150.0  [Japanese Language]
# 450666                       NaN          129.0   [English Language]
# 450667                       NaN          129.0   [English Language]
# 450668                       NaN          129.0   [English Language]
#
#                    movie_countries  \
# 0       [United States of America]
# 1       [United States of America]
# 2       [United States of America]
# 3       [United States of America]
# 4       [United States of America]
# ...                            ...
# 450664                     [Japan]
# 450665                     [Japan]
# 450666            [United Kingdom]
# 450667            [United Kingdom]
# 450668            [United Kingdom]
#
#                                              movie_genres
# 0       [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Thriller, Science Fiction, Horror, Adventure,...
# 2       [Thriller, Science Fiction, Horror, Adventure,...
# 3       [Thriller, Science Fiction, Horror, Adventure,...
# 4       [Thriller, Science Fiction, Horror, Adventure,...
# ...                                                   ...
# 450664  [Science Fiction, Japanese Movies, Adventure, ...
# 450665  [Science Fiction, Japanese Movies, Adventure, ...
# 450666                                    [Crime Fiction]
# 450667                                    [Crime Fiction]
# 450668                                    [Crime Fiction]
#
# [450669 rows x 19 columns]

# %%
# save to processed_files
char_actor_movie_data_new.to_csv("./processed_files/char_actor_movie_data_new.csv")

# %%
# 一些处理Dataframe中list的操作

# 按list长度筛选dataframe，可以用.map(len)或者.str.len()
char_actor_movie_data_new[char_actor_movie_data_new["movie_genres"].map(len) ==0]
# Out:
#         wiki_movie_id freebase_movie_id Movie_release_date character_name  \
# 71           32456683        /m/0gyryjt               1967            NaN
# 194          21153158        /m/05c4bry         2008-11-01            NaN
# 851           6795107         /m/0gp9cf         1998-05-15         Janaki
# 852           6795107         /m/0gp9cf         1998-05-15          Jeeva
# 853           6795107         /m/0gp9cf         1998-05-15          Divya
# ...               ...               ...                ...            ...
# 450102       31078991        /m/0gg8qhs                NaN            NaN
# 450103       31078991        /m/0gg8qhs                NaN            NaN
# 450104       31078991        /m/0gg8qhs                NaN            NaN
# 450105       31078991        /m/0gg8qhs                NaN            NaN
# 450164       20904016        /m/05b1yb1               1977            NaN
#
#          actor_dob actor_gender  actor_height actor_ethnicity  \
# 71      1906-12-27            M           NaN             NaN
# 194     1971-07-31            M           NaN             NaN
# 851     1952-12-10            F           NaN      /m/0dryh9k
# 852     1971-05-01            M          1.80       /m/029f2r
# 853     1976-04-04            F          1.67       /m/02sch9
# ...            ...          ...           ...             ...
# 450102  1951-07-31            M           NaN             NaN
# 450103         NaN            M           NaN             NaN
# 450104  1953-04-16            M           NaN             NaN
# 450105  1943-05-26            F           NaN             NaN
# 450164  1938-07-09            M           NaN       /m/0g0x7_
#
#                actor_name  actor_age_at_movie_release  \
# 71      Erwin Geschonneck                        60.0
# 194                 John5                        37.0
# 851               Sujatha                        45.0
# 852           Ajith Kumar                        27.0
# 853          Simran Bagga                        22.0
# ...                   ...                         ...
# 450102        Sarath Babu                         NaN
# 450103     S. S. Chandran                         NaN
# 450104     Nizhalgal Ravi                         NaN
# 450105           Manorama                         NaN
# 450164      Sanjeev Kumar                        38.0
#
#        freebase_character_actor_map_id freebase_character_id  \
# 71                          /m/0h40xcx                   NaN
# 194                         /m/0gz13sk                   NaN
# 851                         /m/0gggb1x            /m/0h80gh5
# 852                         /m/03lrqwh            /m/0gz5c8p
# 853                         /m/03jrljm            /m/0j8pr2s
# ...                                ...                   ...
# 450102                      /m/0ggcs71                   NaN
# 450103                      /m/0ggdlb4                   NaN
# 450104                      /m/0ggdt4d                   NaN
# 450105                      /m/0ggfhk2                   NaN
# 450164                      /m/0k2fll5                   NaN
#
#        freebase_actor_id                 movie_name  movie_box_office_revenue  \
# 71            /m/02qyp1n   Die Fahne von Kriwoj Rog                       NaN
# 194           /m/01q_wyj  Behind The Player: John 5                       NaN
# 851           /m/04ygpmd              Aval Varuvala                       NaN
# 852            /m/06c53w              Aval Varuvala                       NaN
# 853            /m/04cmrt              Aval Varuvala                       NaN
# ...                  ...                        ...                       ...
# 450102        /m/03nr4s4             Thendral Sudum                       NaN
# 450103        /m/02w30x4             Thendral Sudum                       NaN
# 450104        /m/04n24yj             Thendral Sudum                       NaN
# 450105         /m/07_bv_             Thendral Sudum                       NaN
# 450164         /m/02jxsq                    Angaare                       NaN
#
#         movie_runtime    movie_languages               movie_countries  \
# 71              108.0  [German Language]  [German Democratic Republic]
# 194              72.0                 []                            []
# 851             145.0   [Tamil Language]                            []
# 852             145.0   [Tamil Language]                            []
# 853             145.0   [Tamil Language]                            []
# ...               ...                ...                           ...
# 450102          180.0   [Tamil Language]                       [India]
# 450103          180.0   [Tamil Language]                       [India]
# 450104          180.0   [Tamil Language]                       [India]
# 450105          180.0   [Tamil Language]                       [India]
# 450164            NaN   [Hindi Language]                       [India]
#
#        movie_genres
# 71               []
# 194              []
# 851              []
# 852              []
# 853              []
# ...             ...
# 450102           []
# 450103           []
# 450104           []
# 450105           []
# 450164           []
#
# [4147 rows x 19 columns]

# %%
char_actor_movie_data_new[char_actor_movie_data_new["movie_genres"].str.len() ==0]
# Out:
#         wiki_movie_id freebase_movie_id Movie_release_date character_name  \
# 71           32456683        /m/0gyryjt               1967            NaN
# 194          21153158        /m/05c4bry         2008-11-01            NaN
# 851           6795107         /m/0gp9cf         1998-05-15         Janaki
# 852           6795107         /m/0gp9cf         1998-05-15          Jeeva
# 853           6795107         /m/0gp9cf         1998-05-15          Divya
# ...               ...               ...                ...            ...
# 450102       31078991        /m/0gg8qhs                NaN            NaN
# 450103       31078991        /m/0gg8qhs                NaN            NaN
# 450104       31078991        /m/0gg8qhs                NaN            NaN
# 450105       31078991        /m/0gg8qhs                NaN            NaN
# 450164       20904016        /m/05b1yb1               1977            NaN
#
#          actor_dob actor_gender  actor_height actor_ethnicity  \
# 71      1906-12-27            M           NaN             NaN
# 194     1971-07-31            M           NaN             NaN
# 851     1952-12-10            F           NaN      /m/0dryh9k
# 852     1971-05-01            M          1.80       /m/029f2r
# 853     1976-04-04            F          1.67       /m/02sch9
# ...            ...          ...           ...             ...
# 450102  1951-07-31            M           NaN             NaN
# 450103         NaN            M           NaN             NaN
# 450104  1953-04-16            M           NaN             NaN
# 450105  1943-05-26            F           NaN             NaN
# 450164  1938-07-09            M           NaN       /m/0g0x7_
#
#                actor_name  actor_age_at_movie_release  \
# 71      Erwin Geschonneck                        60.0
# 194                 John5                        37.0
# 851               Sujatha                        45.0
# 852           Ajith Kumar                        27.0
# 853          Simran Bagga                        22.0
# ...                   ...                         ...
# 450102        Sarath Babu                         NaN
# 450103     S. S. Chandran                         NaN
# 450104     Nizhalgal Ravi                         NaN
# 450105           Manorama                         NaN
# 450164      Sanjeev Kumar                        38.0
#
#        freebase_character_actor_map_id freebase_character_id  \
# 71                          /m/0h40xcx                   NaN
# 194                         /m/0gz13sk                   NaN
# 851                         /m/0gggb1x            /m/0h80gh5
# 852                         /m/03lrqwh            /m/0gz5c8p
# 853                         /m/03jrljm            /m/0j8pr2s
# ...                                ...                   ...
# 450102                      /m/0ggcs71                   NaN
# 450103                      /m/0ggdlb4                   NaN
# 450104                      /m/0ggdt4d                   NaN
# 450105                      /m/0ggfhk2                   NaN
# 450164                      /m/0k2fll5                   NaN
#
#        freebase_actor_id                 movie_name  movie_box_office_revenue  \
# 71            /m/02qyp1n   Die Fahne von Kriwoj Rog                       NaN
# 194           /m/01q_wyj  Behind The Player: John 5                       NaN
# 851           /m/04ygpmd              Aval Varuvala                       NaN
# 852            /m/06c53w              Aval Varuvala                       NaN
# 853            /m/04cmrt              Aval Varuvala                       NaN
# ...                  ...                        ...                       ...
# 450102        /m/03nr4s4             Thendral Sudum                       NaN
# 450103        /m/02w30x4             Thendral Sudum                       NaN
# 450104        /m/04n24yj             Thendral Sudum                       NaN
# 450105         /m/07_bv_             Thendral Sudum                       NaN
# 450164         /m/02jxsq                    Angaare                       NaN
#
#         movie_runtime    movie_languages               movie_countries  \
# 71              108.0  [German Language]  [German Democratic Republic]
# 194              72.0                 []                            []
# 851             145.0   [Tamil Language]                            []
# 852             145.0   [Tamil Language]                            []
# 853             145.0   [Tamil Language]                            []
# ...               ...                ...                           ...
# 450102          180.0   [Tamil Language]                       [India]
# 450103          180.0   [Tamil Language]                       [India]
# 450104          180.0   [Tamil Language]                       [India]
# 450105          180.0   [Tamil Language]                       [India]
# 450164            NaN   [Hindi Language]                       [India]
#
#        movie_genres
# 71               []
# 194              []
# 851              []
# 852              []
# 853              []
# ...             ...
# 450102           []
# 450103           []
# 450104           []
# 450105           []
# 450164           []
#
# [4147 rows x 19 columns]
